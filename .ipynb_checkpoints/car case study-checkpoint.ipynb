# %% [markdown]
# # Importing the relevent libraries

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
sns.set()

# %% [markdown]
# # Loading the raw Data

# %%
raw_data = pd.read_csv("1.04. Real-life example.csv")

# %%
raw_data
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277      2.0      Petrol
# 1     Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3              Audi   23000.0  crossover      240      4.2      Petrol
# 4            Toyota   18300.0  crossover      120      2.0      Petrol
# ...             ...       ...        ...      ...      ...         ...
# 4340  Mercedes-Benz  125000.0      sedan        9      3.0      Diesel
# 4341            BMW    6500.0      sedan        1      3.5      Petrol
# 4342            BMW    8000.0      sedan      194      2.0      Petrol
# 4343         Toyota   14200.0      sedan       31      NaN      Petrol
# 4344     Volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration  Year              Model
# 0             yes  1991                320
# ...

# %% [markdown]
# # Preprocessing

# %%
raw_data.describe(include = "all")
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         4345    4173.000000   4345  4345.000000  4195.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           936            NaN   1649          NaN          NaN
# mean           NaN   19418.746935    NaN   161.237284     2.790734
# std            NaN   25584.242620    NaN   105.705797     5.066437
# min            NaN     600.000000    NaN     0.000000     0.600000
# 25%            NaN    6999.000000    NaN    86.000000     1.800000
# 50%            NaN   11500.000000    NaN   155.000000     2.200000
# 75%            NaN   21700.000000    NaN   230.000000     3.000000
# max            NaN  300000.000000    NaN   980.000000    99.990000
#
#        Engine Type Registration         Year    Model
# count         4345         4345  4345.000000     4345
# ...

# %%
data = raw_data.drop(["Model"], axis=1)
data.describe(include ="all")
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         4345    4173.000000   4345  4345.000000  4195.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           936            NaN   1649          NaN          NaN
# mean           NaN   19418.746935    NaN   161.237284     2.790734
# std            NaN   25584.242620    NaN   105.705797     5.066437
# min            NaN     600.000000    NaN     0.000000     0.600000
# 25%            NaN    6999.000000    NaN    86.000000     1.800000
# 50%            NaN   11500.000000    NaN   155.000000     2.200000
# 75%            NaN   21700.000000    NaN   230.000000     3.000000
# max            NaN  300000.000000    NaN   980.000000    99.990000
#
#        Engine Type Registration         Year
# count         4345         4345  4345.000000
# unique           4            2          NaN
# ...

# %% [markdown]
# # Dealing with missing values

# %%
data.isnull().sum()
# Out:
# Brand             0
# Price           172
# Body              0
# Mileage           0
# EngineV         150
# Engine Type       0
# Registration      0
# Year              0
# dtype: int64

# %%
data_no_mv = data.dropna(axis = 0)

# %%
data_no_mv.describe(include="all")
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         4025    4025.000000   4025  4025.000000  4025.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           880            NaN   1534          NaN          NaN
# mean           NaN   19552.308065    NaN   163.572174     2.764586
# std            NaN   25815.734988    NaN   103.394703     4.935941
# min            NaN     600.000000    NaN     0.000000     0.600000
# 25%            NaN    6999.000000    NaN    90.000000     1.800000
# 50%            NaN   11500.000000    NaN   158.000000     2.200000
# 75%            NaN   21900.000000    NaN   230.000000     3.000000
# max            NaN  300000.000000    NaN   980.000000    99.990000
#
#        Engine Type Registration         Year
# count         4025         4025  4025.000000
# unique           4            2          NaN
# ...

# %% [markdown]
# # Exploring the PDFs

# %%
sns.distplot(data_no_mv["Price"])
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
q = data_no_mv["Price"].quantile(0.99)
q
# Out:
# 129812.51999999981

# %%
data_1 = data_no_mv[data_no_mv["Price"] <q]
data_1.describe(include = "all")
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         3984    3984.000000   3984  3984.000000  3984.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           880            NaN   1528          NaN          NaN
# mean           NaN   17837.117460    NaN   165.116466     2.743770
# std            NaN   18976.268315    NaN   102.766126     4.956057
# min            NaN     600.000000    NaN     0.000000     0.600000
# 25%            NaN    6980.000000    NaN    93.000000     1.800000
# 50%            NaN   11400.000000    NaN   160.000000     2.200000
# 75%            NaN   21000.000000    NaN   230.000000     3.000000
# max            NaN  129222.000000    NaN   980.000000    99.990000
#
#        Engine Type Registration         Year
# count         3984         3984  3984.000000
# unique           4            2          NaN
# ...

# %%
sns.distplot(data_1["Price"])
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.distplot(data_no_mv['Mileage'])
# Out:
# <Axes: xlabel='Mileage', ylabel='Density'>

# %%
q = data_1["Mileage"].quantile(0.99)
data_2 = data_1[data["Mileage"]<q]

# %%
sns.distplot(data_2["Mileage"])
# Out:
# <Axes: xlabel='Mileage', ylabel='Density'>

# %%
sns.distplot(x = data_no_mv["EngineV"])
# Out:
# <Axes: ylabel='Density'>

# %%
data_3 = data_2[data_2["EngineV"]<6.5]

# %%
sns.distplot(data_3["EngineV"])
# Out:
# <Axes: xlabel='EngineV', ylabel='Density'>

# %%
sns.distplot(x = data_no_mv["Year"])
# Out:
# <Axes: ylabel='Density'>

# %%
q = data_3["Year"].quantile(0.01)
data_4 = data_3[data_3["Year"]>q]

# %%
sns.distplot(x = data_4["Year"])
# Out:
# <Axes: ylabel='Density'>

# %%
data_clean = data_4.reset_index(drop =True)
data_clean
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277      2.0      Petrol
# 1     Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3              Audi   23000.0  crossover      240      4.2      Petrol
# 4            Toyota   18300.0  crossover      120      2.0      Petrol
# ...             ...       ...        ...      ...      ...         ...
# 3862     Volkswagen   11500.0        van      163      2.5      Diesel
# 3863         Toyota   17900.0      sedan       35      1.6      Petrol
# 3864  Mercedes-Benz  125000.0      sedan        9      3.0      Diesel
# 3865            BMW    6500.0      sedan        1      3.5      Petrol
# 3866     Volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration  Year
# 0             yes  1991
# 1             yes  1999
# 2             yes  2003
# ...

# %% [markdown]
# # Checking the OLS assumption

# %%
f, (ax1,ax2,ax3) = plt.subplots(1, 3, sharey=True, figsize= (15,3))
ax1.scatter(data_clean['Year'],data_clean["Price"])
ax1.set_title("price and year")
ax2.scatter(data_clean['EngineV'],data_clean["Price"])
ax2.set_title("EngineV and year")
ax3.scatter(data_clean['Mileage'],data_clean["Price"])
ax3.set_title("Mileage and year")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # relaxing the assumption

# %%
log_price = np.log(data_clean["Price"])
data_clean["log_price"] = log_price
data_clean
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277      2.0      Petrol
# 1     Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3              Audi   23000.0  crossover      240      4.2      Petrol
# 4            Toyota   18300.0  crossover      120      2.0      Petrol
# ...             ...       ...        ...      ...      ...         ...
# 3862     Volkswagen   11500.0        van      163      2.5      Diesel
# 3863         Toyota   17900.0      sedan       35      1.6      Petrol
# 3864  Mercedes-Benz  125000.0      sedan        9      3.0      Diesel
# 3865            BMW    6500.0      sedan        1      3.5      Petrol
# 3866     Volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration  Year  log_price
# 0             yes  1991   8.342840
# 1             yes  1999   8.974618
# ...

# %%
f, (ax1,ax2,ax3) = plt.subplots(1, 3, sharey=True, figsize= (15,3))
ax1.scatter(data_clean['Year'],data_clean["log_price"])
ax1.set_title("price and year")
ax2.scatter(data_clean['EngineV'],data_clean["log_price"])
ax2.set_title("EngineV and year")
ax3.scatter(data_clean['Mileage'],data_clean["log_price"])
ax3.set_title("Mileage and year")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Multicollinearity

# %%
data_clean.columns
# Out:
# Index(['Brand', 'Price', 'Body', 'Mileage', 'EngineV', 'Engine Type',
#        'Registration', 'Year', 'log_price'],
#       dtype='object')

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
variables =  data_clean[["Mileage","Year","EngineV"]]
vif = pd.DataFrame()
vif["VIF"] = [variance_inflation_factor(variables.values,i)for i in range(variables.shape[1])]
vif["features"] = variables.columns

# %%
vif
# Out:
#          VIF features
# 0   3.791584  Mileage
# 1  10.354854     Year
# 2   7.662068  EngineV

# %% [raw]
# VIF = 1: no multicollinearity
# 1<VIF <5: perfectly okay
# 10< VIF: unacceptable

# %%
data_no_multico = data_clean.drop(["Year"], axis =1)

# %%
data_no_multico
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277      2.0      Petrol
# 1     Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3              Audi   23000.0  crossover      240      4.2      Petrol
# 4            Toyota   18300.0  crossover      120      2.0      Petrol
# ...             ...       ...        ...      ...      ...         ...
# 3862     Volkswagen   11500.0        van      163      2.5      Diesel
# 3863         Toyota   17900.0      sedan       35      1.6      Petrol
# 3864  Mercedes-Benz  125000.0      sedan        9      3.0      Diesel
# 3865            BMW    6500.0      sedan        1      3.5      Petrol
# 3866     Volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration  log_price
# 0             yes   8.342840
# 1             yes   8.974618
# ...

# %% [markdown]
# # creating Dummy variables

# %%
data_with_dummies = pd.get_dummies(data_no_multico, drop_first=True)
data_with_dummies
# Out:
#          Price  Mileage  EngineV  log_price  Brand_BMW  Brand_Mercedes-Benz  \
# 0       4200.0      277      2.0   8.342840       True                False
# 1       7900.0      427      2.9   8.974618      False                 True
# 2      13300.0      358      5.0   9.495519      False                 True
# 3      23000.0      240      4.2  10.043249      False                False
# 4      18300.0      120      2.0   9.814656      False                False
# ...        ...      ...      ...        ...        ...                  ...
# 3862   11500.0      163      2.5   9.350102      False                False
# 3863   17900.0       35      1.6   9.792556      False                False
# 3864  125000.0        9      3.0  11.736069      False                 True
# 3865    6500.0        1      3.5   8.779557       True                False
# 3866   13500.0      124      2.0   9.510445      False                False
#
# ...

# %%
data_with_dummies.columns.values
# Out:
# array(['Price', 'Mileage', 'EngineV', 'log_price', 'Brand_BMW',
#        'Brand_Mercedes-Benz', 'Brand_Mitsubishi', 'Brand_Renault',
#        'Brand_Toyota', 'Brand_Volkswagen', 'Body_hatch', 'Body_other',
#        'Body_sedan', 'Body_vagon', 'Body_van', 'Engine Type_Gas',
#        'Engine Type_Other', 'Engine Type_Petrol', 'Registration_yes'],
#       dtype=object)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
variables =  data_with_dummies[['Brand_BMW',
       'Brand_Mercedes-Benz', 'Brand_Mitsubishi', 'Brand_Renault',
       'Brand_Toyota', 'Brand_Volkswagen', 'Body_hatch', 'Body_other',
       'Body_sedan', 'Body_vagon', 'Body_van', 'Engine Type_Gas',
       'Engine Type_Other', 'Engine Type_Petrol', 'Registration_yes']]
vif = pd.DataFrame()
vif["VIF"] = [variance_inflation_factor(variables.values,i)for i in range(variables.shape[1])]
vif["features"] = variables.columns

# %%
vif
# Out:
#          VIF             features
# 0   0.003105            Brand_BMW
# 1   0.003188  Brand_Mercedes-Benz
# 2   0.005305     Brand_Mitsubishi
# 3   0.004808        Brand_Renault
# 4   0.004049         Brand_Toyota
# 5   0.003238     Brand_Volkswagen
# 6   0.005398           Body_hatch
# 7   0.003891           Body_other
# 8   0.001801           Body_sedan
# 9   0.003623           Body_vagon
# 10  0.003499             Body_van
# 11  0.002876      Engine Type_Gas
# 12  0.010908    Engine Type_Other
# 13  0.001755   Engine Type_Petrol
# 14  0.002174     Registration_yes

# %%
cols = ['log_price', 'Mileage', 'EngineV', 'Brand_BMW',
       'Brand_Mercedes-Benz', 'Brand_Mitsubishi', 'Brand_Renault',
       'Brand_Toyota', 'Brand_Volkswagen', 'Body_hatch', 'Body_other',
       'Body_sedan', 'Body_vagon', 'Body_van', 'Engine Type_Gas',
       'Engine Type_Other', 'Engine Type_Petrol', 'Registration_yes']

# %%
data_preprocessed = data_with_dummies[cols]

# %%
data_preprocessed
# Out:
#       log_price  Mileage  EngineV  Brand_BMW  Brand_Mercedes-Benz  \
# 0      8.342840      277      2.0       True                False
# 1      8.974618      427      2.9      False                 True
# 2      9.495519      358      5.0      False                 True
# 3     10.043249      240      4.2      False                False
# 4      9.814656      120      2.0      False                False
# ...         ...      ...      ...        ...                  ...
# 3862   9.350102      163      2.5      False                False
# 3863   9.792556       35      1.6      False                False
# 3864  11.736069        9      3.0      False                 True
# 3865   8.779557        1      3.5       True                False
# 3866   9.510445      124      2.0      False                False
#
#       Brand_Mitsubishi  Brand_Renault  Brand_Toyota  Brand_Volkswagen  \
# 0                False          False         False             False
# ...

# %% [markdown]
# # Linear Regression model

# %% [markdown]
# # declear the input and targets

# %%
targets = data_preprocessed["log_price"]

# %%
inputs = data_preprocessed.drop(["log_price"],axis=1)
inputs
# Out:
#       Mileage  EngineV  Brand_BMW  Brand_Mercedes-Benz  Brand_Mitsubishi  \
# 0         277      2.0       True                False             False
# 1         427      2.9      False                 True             False
# 2         358      5.0      False                 True             False
# 3         240      4.2      False                False             False
# 4         120      2.0      False                False             False
# ...       ...      ...        ...                  ...               ...
# 3862      163      2.5      False                False             False
# 3863       35      1.6      False                False             False
# 3864        9      3.0      False                 True             False
# 3865        1      3.5       True                False             False
# 3866      124      2.0      False                False             False
#
#       Brand_Renault  Brand_Toyota  Brand_Volkswagen  Body_hatch  Body_other  \
# ...

# %% [markdown]
# # scale the data

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler.fit(inputs)
# Out:
# StandardScaler()

# %%
input_scaled = scaler.transform(inputs)

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(input_scaled,targets, test_size = 0.2, random_state = 365)

# %% [markdown]
# # create the regression

# %%
reg = LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_hat = reg.predict(x_train)

# %%
plt.scatter(y_train,y_hat)
plt.xlabel('Target (y_train)')
plt.ylabel('Predictions (y_hat)')
plt.xlim(6,13)
plt.ylim(6,13)
plt.show()

# %%
sns.distplot(y_train-y_hat)
# Out:
# <Axes: xlabel='log_price', ylabel='Density'>

# %%
reg.score(x_train,y_train)
# Out:
# 0.744996578792662

# %% [markdown]
# # Finding the weights and bias

# %%
reg.intercept_
# Out:
# 9.415239458021299

# %%
reg.coef_
# Out:
# array([-0.44871341,  0.20903483,  0.0142496 ,  0.01288174, -0.14055166,
#        -0.17990912, -0.06054988, -0.08992433, -0.1454692 , -0.10144383,
#        -0.20062984, -0.12988747, -0.16859669, -0.12149035, -0.03336798,
#        -0.14690868,  0.32047333])

# %%
reg_summary = pd.DataFrame(inputs.columns.values, columns = ["Features"])
reg_summary["weights"] = reg.coef_
reg_summary
# Out:
#                Features   weights
# 0               Mileage -0.448713
# 1               EngineV  0.209035
# 2             Brand_BMW  0.014250
# 3   Brand_Mercedes-Benz  0.012882
# 4      Brand_Mitsubishi -0.140552
# 5         Brand_Renault -0.179909
# 6          Brand_Toyota -0.060550
# 7      Brand_Volkswagen -0.089924
# 8            Body_hatch -0.145469
# 9            Body_other -0.101444
# 10           Body_sedan -0.200630
# 11           Body_vagon -0.129887
# 12             Body_van -0.168597
# 13      Engine Type_Gas -0.121490
# 14    Engine Type_Other -0.033368
# 15   Engine Type_Petrol -0.146909
# 16     Registration_yes  0.320473

# %% [raw]
# Weights interpretation ---------->
# positive weight shows that as a feature increases in value so the log_price and price respectively
#
# -ve weight shows that as a feature increases in value so the log_price and price decreases
#
# Dummy Variable ----------------->
# positive weight shows that the resp category(band) is more expensive than the benchmark(Audi)
#
# -ve weight shows that the respecti cat is less expensive than the benchmark(audi)

# %%
y_hat_test = reg.predict(x_test)

# %%
plt.scatter(y_test,y_hat_test,alpha=0.2)
plt.xlabel("Targent (y_test)")
plt.ylabel("Prediction (y_hat_test)")
plt.xlim(6,13)
plt.ylim(6,13)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_pf = pd.DataFrame(np.exp(y_hat_test), columns=["Prediciton"])

# %%
df_pf
# Out:
#        Prediciton
# 0    10685.501696
# 1     3499.255242
# 2     7553.285218
# 3     7463.963017
# 4    11353.490075
# ..            ...
# 769  29651.726363
# 770  10732.071179
# 771  13922.446953
# 772  27487.751303
# 773  13491.163043
#
# [774 rows x 1 columns]

# %%
df_pf["Target"] = np.exp(y_test)

# %%
y_test = y_test.reset_index(drop=True)

# %%
df_pf
# Out:
#        Prediciton   Target
# 0    10685.501696   2300.0
# 1     3499.255242   2800.0
# 2     7553.285218   2500.0
# 3     7463.963017   6400.0
# 4    11353.490075   9150.0
# ..            ...      ...
# 769  29651.726363  29500.0
# 770  10732.071179   9600.0
# 771  13922.446953  18300.0
# 772  27487.751303  68500.0
# 773  13491.163043  10800.0
#
# [774 rows x 2 columns]

# %%
df_pf["Residual"] = df_pf["Target"] - df_pf["Prediciton"]

# %%
df_pf["Difference%"] = np.absolute(df_pf["Residual"]/df_pf["Target"]*100)

# %%
df_pf
# Out:
#        Prediciton   Target      Residual  Difference%
# 0    10685.501696   2300.0  -8385.501696   364.587030
# 1     3499.255242   2800.0   -699.255242    24.973402
# 2     7553.285218   2500.0  -5053.285218   202.131409
# 3     7463.963017   6400.0  -1063.963017    16.624422
# 4    11353.490075   9150.0  -2203.490075    24.081859
# ..            ...      ...           ...          ...
# 769  29651.726363  29500.0   -151.726363     0.514327
# 770  10732.071179   9600.0  -1132.071179    11.792408
# 771  13922.446953  18300.0   4377.553047    23.921055
# 772  27487.751303  68500.0  41012.248697    59.871896
# 773  13491.163043  10800.0  -2691.163043    24.918176
#
# [774 rows x 4 columns]

# %%
df_pf.describe(include ="all")
# Out:
#          Prediciton         Target      Residual  Difference%
# count    774.000000     774.000000    774.000000   774.000000
# mean   15946.760167   18165.817106   2219.056939    36.256693
# std    13133.197604   19967.858908  10871.218143    55.066507
# min     1320.562768    1200.000000 -29456.498331     0.062794
# 25%     7413.644234    6900.000000  -2044.191251    12.108022
# 50%    11568.168859   11600.000000    142.518577    23.467728
# 75%    20162.408805   20500.000000   3147.343497    39.563570
# max    77403.055224  126000.000000  85106.162329   512.688080

# %%
pd.options.display.max_rows = 999
pd.set_option("display.float_format",lambda x: '%.2f' % x )
df_pf.sort_values(by= "Difference%")
# Out:
#      Prediciton    Target  Residual  Difference%
# 698    30480.85  30500.00     19.15         0.06
# 742    16960.31  16999.00     38.69         0.23
# 60     12469.21  12500.00     30.79         0.25
# 110    25614.14  25500.00   -114.14         0.45
# 367    42703.68  42500.00   -203.68         0.48
# 369     3084.69   3100.00     15.31         0.49
# 769    29651.73  29500.00   -151.73         0.51
# 272     9749.53   9800.00     50.47         0.52
# 714    23118.07  22999.00   -119.07         0.52
# 630     8734.58   8800.00     65.42         0.74
# 380     3473.79   3500.00     26.21         0.75
# 648    21174.10  21335.00    160.90         0.75
# 308     8967.74   8900.00    -67.74         0.76
# 665    17858.02  18000.00    141.98         0.79
# 379    17654.84  17800.00    145.16         0.82
# 719    11391.95  11500.00    108.05         0.94
# 102    28625.56  28900.00    274.44         0.95
# 94      7724.17   7800.00     75.83         0.97
# ...
